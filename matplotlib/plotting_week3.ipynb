# %%
#provides an interactive environment - backend nbagg
# %matplotlib notebook 

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
plt.figure()
linear_data = np.array([1,2,3,4,5,6,7,8])
exponential_data = linear_data**2
observation_dates = np.arange('2017-01-01', '2017-01-09', dtype='datetime64')
import pandas as pd
observation_dates = list(map(pd.to_datetime, observation_dates))
plt.plot(observation_dates, linear_data, '-o',  observation_dates, exponential_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="740">
# ...

# %%
from matplotlib.artist import Artist

x=plt.gca().xaxis
for item in x.get_ticklabels():
    item.set_rotation(45)

# %%
plt.subplots_adjust(bottom=0.25)

# %%
ax=plt.gca()
ax.set_title("Exponential ($x^2$) vs. Linear ($x$) performance")
# Out:
# Text(0.5,1,'Exponential ($x^2$) vs. Linear ($x$) performance')

# %% [markdown]
# ## Bar Charts

# %%
xvals=range(len(linear_data))
plt.figure()
plt.bar(xvals, linear_data, width=0.3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 8 artists>

# %%
new_xvals = []

# plot another set of bars, adjusting the new xvals to make up for the first set of bars plotted
for item in xvals:
    new_xvals.append(item+0.3)

plt.bar(new_xvals, exponential_data, width = 0.3 ,color='red')
# Out:
# <Container object of 8 artists>

# %% [markdown]
# ## Subplots

# %%
plt.subplot?

# %%
plt.figure()
ax1=plt.subplot(1,2,1)

linear_data=np.array(np.arange(1,9))
ax1.plot(linear_data, '-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
exponential_data = linear_data**2
ax2=plt.subplot(1,2,2, sharey=ax1)
ax2.plot(exponential_data, '-o')

# %%
ax1.plot(exponential_data, '-x')

# %%
fig, ((ax1,ax2,ax3), (ax4,ax5,ax6), (ax7,ax8,ax9))=plt.subplots(3,3, sharex=True, sharey=True)

ax5.plot(linear_data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for ax in plt.gcf().get_axes():
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_visible(True)

# %%
plt.gcf().canvas.draw()

# %%
fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(2,2,sharex=True)

axs=[ax1,ax2,ax3,ax4]

for n in range(0, len(axs)):
    sample_size = 10**(n+1)
    sample = np.random.normal(loc=00.0, scale=1.0, size=sample_size)
    axs[n].hist(sample, bins=200)
    axs[n].set_title('n={}'.format(sample_size))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()

Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)

plt.scatter(X,Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib.gridspec as gridspec

plt.figure()
gspec = gridspec.GridSpec(3,3)

top_histogram = plt.subplot(gspec[0, 1:])
side_histogram = plt.subplot(gspec[1:, 0])
lower_right = plt.subplot(gspec[1:, 1:])

Y = np.random.normal(loc=0.0, scale=1.0, size=10000)
X = np.random.random(size=10000)

lower_right.scatter(X,Y,s=2)
tup1=top_histogram.hist(X, bins=100, normed=True)
tup2=side_histogram.hist(Y, bins=100, orientation='horizontal', normed=True)

side_histogram.invert_xaxis()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for ax in [top_histogram, lower_right]:
    ax.set_xlim(0,1)
    
for ax in [side_histogram, lower_right]:
    ax.set_ylim(-5,5)

# %%
import pandas as pd
normal_sample = np.random.normal(loc=0.0, scale=1.0, size=10000)
random_sample = np.random.random(size=10000)
gamma_sample = np.random.gamma(2, size=10000)

df = pd.DataFrame({'normal' : normal_sample,
                  'random' : random_sample,
                  'gamma' : gamma_sample})

# %%
df.describe()
# Out:
#               gamma        normal        random
# count  10000.000000  10000.000000  10000.000000
# mean       1.987370      0.008006      0.502224
# std        1.384780      1.000251      0.287320
# min        0.005375     -3.646086      0.000085
# 25%        0.966707     -0.658326      0.254496
# 50%        1.684958      0.004692      0.502083
# 75%        2.679788      0.673924      0.753224
# max       10.788300      3.625080      0.999955

# %%
plt.figure()
gspec = gridspec.GridSpec(1,3)
first=plt.subplot(gspec[0,0])
_ = plt.boxplot(df['normal'], whis='range')
second=plt.subplot(gspec[0,1])
_ = plt.boxplot(df['random'], whis='range')
third=plt.subplot(gspec[0,2])
_ = plt.boxplot(df['gamma'], whis='range')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.clf()
_ = plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')

# %%
plt.figure()
_ = plt.hist([df['normal'], df['gamma']], bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import mpl_toolkits.axes_grid1.inset_locator as mpl_il

plt.figure()
_ = plt.boxplot([df['normal'], df['random'], df['gamma']], whis='range')

ax2= mpl_il.inset_axes(plt.gca(), width='50%', height='35%', loc=2)
ax2.hist(df['gamma'], bins=100)
ax2.margins(x=0.5)
ax2.yaxis.tick_right()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
_ = plt.boxplot([df['normal'], df['random'], df['gamma']])
# Out:
# <img src="data:image/png;base64,..." width="718">

# %% [markdown]
# ## Heatmaps

# %%
plt.figure()

Y = np.random.normal(loc=0.0, scale=1.0, size=1000000)
X = np.random.random(size=1000000)

_ = plt.hist2d(X, Y, bins=100)
plt.xlabel("Random distribution {} numbers".format(len(X)))
plt.ylabel("Normal distribution {} numbers".format(len(Y)))
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Animation

# %%
import matplotlib.animation as animation

n = 100
x = np.random.randn(n)

# %%
def update(curr):
    if curr == n:
        a.event_source.stop()
    plt.cla()
    bins = np.arange(-4, 4, 0.5)
    plt.hist(x[:curr], bins=bins)
    plt.axis([-4, 4, 0, 30])
    plt.gca().set_title('Sampling the normal distribution')
    plt.gca().set_ylabel('Frequency')
    plt.gca().set_xlabel('Value')
    plt.annotate('n = {}'.format(curr), [3,27])

# %%
fig = plt.figure()
a = animation.FuncAnimation(fig, update, interval=10)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Interactivity

# %%
plt.figure()

data = np.random.randn(10)
plt.plot(data)

def onclick(event):
    plt.cla()
    plt.plot(data)
    plt.gca().set_title('Event at pixel {}, {} {} and data {},{}'.format(
        event.x, event.y,'\n', event.xdata, event.ydata))
    
plt.gcf().canvas.mpl_connect('button_press_event', onclick)
# Out:
# <img src="data:image/png;base64,..." width="640">
# 8

# %%
from random import shuffle
import pandas as pd

origins = ['China', 'Brazil', 'India', 'USA', 'France', 'England', 'Germany', 'Mexico', 'Iraq', 'Chile']
shuffle(origins)

df = pd.DataFrame({'height' : np.random.rand(10),
                  'weight' : np.random.rand(10),
                  'origin' : origins})

df
# Out:
#      height   origin    weight
# 0  0.727506   France  0.900286
# 1  0.059619      USA  0.767641
# 2  0.719465    India  0.216945
# 3  0.504196    China  0.566057
# 4  0.078495  England  0.553017
# 5  0.007191    Chile  0.305678
# 6  0.711328  Germany  0.579183
# 7  0.922176     Iraq  0.715892
# 8  0.005725   Brazil  0.392787
# 9  0.980221   Mexico  0.265528

# %%
plt.figure()
plt.scatter(df['height'], df['weight'], picker=5, label='country origin')
plt.gca().set_ylabel('Weight')
plt.gca().set_xlabel('Height')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def onpick(event):
    origin = df.iloc[event.ind[0]]['origin']
    plt.gca().set_title('Picked item came from '+event)

plt.gcf().canvas.mpl_connect('pick_event', onpick)
# Out:
# 12

# %%
# Out:
# hello
